# %%
from pyspark.sql import SparkSession

catalog_name = "mytest" 

spark = (
    SparkSession.builder
    .appName("local-uc-test")
    .master("spark://spark:7077")
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4,io.delta:delta-spark_2.12:3.2.1,io.unitycatalog:unitycatalog-spark_2.12:0.2.0")
    .config("spark.hadoop.fs.s3.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "io.unitycatalog.spark.UCSingleCatalog")
    .config(f"spark.sql.catalog.{catalog_name}", "io.unitycatalog.spark.UCSingleCatalog")
    .config(f"spark.sql.catalog.{catalog_name}.uri", "http://server:8080")
    .config(f"spark.sql.catalog.{catalog_name}.warehouse", catalog_name)
    # .config(f"spark.sql.catalog.{catalog_name}.token", "eyJraWQiOiI3ZTAwYmE4ZTYzZWVhMjZjYzQ4OTA0ODE0NWE0YzRiMzJjMTFjMDc3ZjQ3NzJmNmMzMGY5OGEyODAyZjIxN2YwIiwiYWxnIjoiUlM1MTIiLCJ0eXAiOiJKV1QifQ.eyJzdWIiOiJ1Y3Rlc3QiLCJpc3MiOiJpbnRlcm5hbCIsImlhdCI6MTc0OTQ1OTk5OSwianRpIjoiM2RlOGRlNmUtNmEzNy00NmNlLThiNjgtOTgxZTU0NDAxYmQ3IiwidHlwZSI6IkFDQ0VTUyJ9.0b5hUU1EMREP_9fclndD9TBhsnkLdGoMP9iqPmUO64wha6Uj9qUUkt299fBIgI8C67Yu5KYVBvj6CRUHomyEB40ngYzV6PHtX0y9_BC3HJHzVf5-OYJXz0CUeqzKvF4BSs-53b4hmD6L_8-nggKZpGQpLHF31xlKMbJkerPzCZiblXjTtzOirIZGIwLNrEtiQUFBzEa5AheFh-Q76oQ_HAacqZGa8jBW_tXLMJpSVXIcr48HDIDkgVRd6gZmWrwqG_sdhqAQIuNXET8SjrF1TmnA61Sbp0B8kpJEkymNg17sA_xSo1-Rkt3FHt3e0nudPmZELvyo7QwH0BDt-sJ0sQ")
    .config(f"spark.sql.catalog.{catalog_name}.token","eyJraWQiOiIzZDc0ZGNlNDA2YmMwNTU5YjlhNjk4MzNiYzliYWM0MmRmNjk1MjRjY2FlYWE4NmU4NGM3MTY4NTY5YzQzN2EwIiwiYWxnIjoiUlM1MTIiLCJ0eXAiOiJKV1QifQ.eyJzdWIiOiJ5b3JrZGljazlAZ21haWwuY29tIiwiaXNzIjoiaW50ZXJuYWwiLCJpYXQiOjE3NDk1NDg0MDYsImp0aSI6IjhlM2FhZWUyLWZjMmEtNGNlZC04ZDYwLTI1YTkyMTgxZWI2ZSIsInR5cGUiOiJBQ0NFU1MifQ.euG5qw72EpcwgsN82wlt8zC3BcANto0ktLxB7E_ZnwyOqjSw5RtOCTninjJ1WefnhQGh3tOLfLzu5w6isIXR2dmxA8XYWuiUkhBB4sStIcCi01DDLSrR3NXZibKkFhymr6GiR-OfdHhIs_MEj0-TsP0tCOocsZe4VQVNYOejpEKPC6oDfRu1RTZku93qRm6zF7Gu072clXgeAwig0jF20NDtXydn289WHGHPk1T_GAQfgQh0ew0ElmxxSsyWD4TJOiAOo6jIv8m7agsG3awFTIp-QpIF4O3TDJ_uqnfIejoEscmdrUglF-qpaCx3x-vP95b0hlDX4CLjOKDCdAG7wA")
    .config("spark.sql.defaultCatalog", catalog_name)
    .config("spark.databricks.delta.catalog.update.enabled","true")
    # .config("spark.sql.session.user", "orkney@test.com")
    # .config("spark.driver.extraJavaOptions", "-Duser.name=orkney@test.com")
    .getOrCreate()
)
# Out:
# :: loading settings :: url = jar:file:/home/uctest/venv/lib/python3.12/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/uctest/.ivy2/cache
# The jars for the packages stored in: /home/uctest/.ivy2/jars
# org.apache.hadoop#hadoop-aws added as a dependency
# io.delta#delta-spark_2.12 added as a dependency
# io.unitycatalog#unitycatalog-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-21066959-f94e-42f6-b351-327421f400c4;1.0
# 	confs: [default]
# 	found org.apache.hadoop#hadoop-aws;3.3.4 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.12.262 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# 	found io.delta#delta-spark_2.12;3.2.1 in central
# 	found io.delta#delta-storage;3.2.1 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# 	found io.unitycatalog#unitycatalog-spark_2.12;0.2.0 in central
# ...

# %%
# Create new schema
schema_name = "myschema"
# spark.sql(f"CREATE SCHEMA {schema_name}")

# Should now show two schemas: default and demo
spark.sql("SHOW SCHEMAS").show()
# Out:
# +---------+
# |namespace|
# +---------+
# | myschema|
# +---------+

# %%
# # Create a new table
table_name = "testTable2"
new_tablename = f"{catalog_name}.{schema_name}.{table_name}"
print(new_tablename)

spark.sql(f"""
CREATE TABLE {new_tablename} (id INT, desc STRING)
USING delta
LOCATION 's3://uctest0001/{catalog_name}/{schema_name}/{table_name}'
""")

spark.sql(f"SELECT * FROM {new_tablename}").show()
spark.sql(f"DESCRIBE TABLE {new_tablename}").show(truncate=False)
# Out:
# mytest.myschema.testTable2

# %%
# spark.sql(f"""INSERT INTO {new_tablename} VALUES (1, "test 1")""")
# spark.sql(f"""INSERT INTO {new_tablename} VALUES (2, "test 2")""")

spark.sql(f"""SELECT * FROM {new_tablename}""").show()
# Out:
# 25/06/11 07:25:58 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 25/06/11 07:26:14 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 10:>                                                         (0 + 1) / 1]
# +---+------+
# | id|  desc|
# +---+------+
# |  2|test 2|
# |  1|test 1|
# +---+------+
